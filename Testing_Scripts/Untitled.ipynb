# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from test_synset import *

generate_synsets()
# Out:
# ...
# loading synsets current build: 100%|██████████| 1775/1775 [00:03<00:00, 482.92it/s]
# n
# r
# v
# ['they', 'talk', 'as', 'slow', 'as', 'legends', 'grow', 'no', 'mushroom', 'is', 'their', 'mind', 'but', 'foliage', 'of', 'sterility', 'too', 'stolid', 'for', 'the', 'wind', 'they', 'laugh', 'as', 'wise', 'as', 'plots', 'of', 'wit', 'predestined', 'to', 'unfold', 'the', 'point', 'with', 'bland', 'prevision', 'portentously', 'untold']
# they : set()
# they : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# talk : {'lecture', 'speak', 'talk', 'spill_the_beans', 'spill'}
# talk : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# as : {'equally'}
# as : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# slow : {'dense', 'boring', 'dull', 'slow'}
# slow : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# as : set()
# as : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# legends : {'legend', 'caption'}
# legends : Synset('heaven.n.02')
#
# Synset('heaven.n.02')
# ...

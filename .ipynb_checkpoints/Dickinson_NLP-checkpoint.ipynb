# %%
import os
import re


# Script for preprocessing complete raw poems; I have to manually fix line breaks
# after this.

infile = "edCompleteRaw.txt"
outfile = "edCompleteFormatted.txt"
outfile2 = "edCompleteFormatted2.txt"

with open(infile, 'r') as raw:
    buff = raw.read().split()

with open(outfile2, 'w') as cleaned:
    
    # Split by poem number
    
    for word in buff:
        
        # Has poem number
        if re.search('[A-Za-z]*[0-9]+', word):
            
            first = ""
            poem_num = ""
            second = ""
            
            for letter in word:
                if re.match('[0-9]', letter):
                    poem_num += str(letter)
                elif len(poem_num) > 0:
                    second += letter
                else:
                    first += letter
            
            cleaned.write(first + "\n\n" + poem_num + "\n\n" + second + ' ')
        
        # Sometimes double quotation marks when they begin consecutive lines
        
        elif re.search('""', word):
            
            first = ""
            second = ""
            
            for letter in word:
                if letter == '"' and first[-1] == '"':
                    second += letter
                elif len(second) > 0:
                    second += letter
                else:
                    first += letter
                    
            cleaned.write(first + "\n" + second + ' ')
        
        # Could be combined word from line break
        # Check for capital letters
        
        elif re.search('[A-Za-z?!-,.;]+[A-Z]', word):
            
            first = ""
            second = ""
            
            for letter in word:
                if letter.isupper() and len(first) > 0:
                    second += letter
                elif len(second) > 0:
                    second += letter
                else:
                    first += letter
            
            cleaned.write(first + "\n" + second + ' ')
    
        # If word begins with capital letter, could be start
        # of new verse. Need to add newline, controlling only
        # for "I"
        
        elif word[0].isupper() and word != 'I':
            
            cleaned.write("\n" + word + ' ')
            
        else:
            cleaned.write(word + ' ')

# %%
l = [(k,v) for k,v in tell.items() if v == None]

l.sort()
print l[:50]
# Out:
# [(323, None), (331, None), (338, None), (340, None), (344, None), (352, None), (354, None), (359, None), (361, None), (365, None), (368, None), (370, None), (379, None), (382, None), (385, None), (393, None), (394, None), (401, None), (403, None), (404, None), (409, None), (410, None), (411, None), (415, None), (432, None), (435, None), (436, None), (445, None), (448, None), (455, None), (467, None), (471, None), (473, None), (475, None), (476, None), (482, None), (496, None), (497, None), (501, None), (505, None), (506, None), (510, None), (515, None), (516, None), (520, None), (521, None), (525, None), (540, None), (550, None), (561, None)]

# %%
tell[323] = ("happiness","surprise")
l = [(k,v) for k,v in tell.items() if v == None]

l.sort()
print l[:50]
# Out:
# [(331, None), (338, None), (340, None), (344, None), (352, None), (354, None), (359, None), (361, None), (365, None), (368, None), (370, None), (379, None), (382, None), (385, None), (393, None), (394, None), (401, None), (403, None), (404, None), (409, None), (410, None), (411, None), (415, None), (432, None), (435, None), (436, None), (445, None), (448, None), (455, None), (467, None), (471, None), (473, None), (475, None), (476, None), (482, None), (496, None), (497, None), (501, None), (505, None), (506, None), (510, None), (515, None), (516, None), (520, None), (521, None), (525, None), (540, None), (550, None), (561, None), (566, None)]

# %%
with open(out, 'r') as go:
    tell = pickle.load(go)
    
l = [(k,v) for k,v in tell.items() if v != None]

l.sort()
print(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-122809cd56e1> in <module>()
# ----> 1 with open(out, 'r') as go:
#       2     tell = pickle.load(go)
#       3
#       4 l = [(k,v) for k,v in tell.items() if v != None]
#       5
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
tags = set([t for i in l for t in i[1]])
print tags
# Out:
# set(['love', 'family', 'autumn', 'weather', 'sleep', 'madness', 'fear', 'children', 'happiness', 'wonder', 'friendship', 'art', 'death', 'hesitation', 'winter', 'peace', 'connection', 'birds', 'frustration', 'memory', 'scorn', 'surprise', 'life', 'woman', 'beauty', 'loss', 'mother', 'trees', 'smallness', 'suffering', 'determination', 'seasons', 'flowers', 'grace', 'science', 'mystery', 'faith', 'sickness', 'freedom', 'work', 'disconnection', 'sadness', 'marriage', 'time', 'salvation', 'nature'])

# %%
import pickle



with open(out, 'rb') as go:
    tell = pickle.load(go)
    
print(tell)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2879c4ae3df3> in <module>()
#       3
#       4
# ----> 5 with open(out, 'rb') as go:
#       6     tell = pickle.load(go)
#       7
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
sent = "SentiWordNet_3.0.0_20130122.txt"
import json

from collections import defaultdict

sent_dict = defaultdict(float)


with open(sent, 'r') as infile:

    for line in infile:
            
            words = line.split()
            
            if words[0] != '#':
                sent_dict[words[4][:words[4].index('#')]] = float(words[2]) - float(words[3])
            

# print (sent_dict)

with open("sent_dict.json", 'w') as out:
    
    json.dump(sent_dict, out)
    
print("done")
# Out:
# done

# %%
'death' in sent_dict
# Out:
# True

# %%
import pickle
import numpy as np

inf = "AS_dict_alpha1.pickle"


with open(inf, 'rb') as infile:
    
    AS_dict = pickle.load(infile)

# k = [k for k in tell.keys()]
# # print(k)

# r = [int(x) for x in np.random.uniform(0,300,20)]
# print(r)

# p = sorted([k[x] for x in r])
# print(p)

k = [120, 287, 393, 411, 566, 669, 691, 702, 841, 919, 1016, 1028, 1041, 1122, 1145, 1299, 1328, 1458, 1516, 1773]

for x in k:
    print(x,":",AS_dict['{}'.format(x)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-9729877d792e> in <module>()
#      21
#      22 for x in k:
# ---> 23     print(x,":",AS_dict['{}'.format(x)])
#      24
#
# KeyError: '120'

# %%
l = [(k,v) for k,v in tell.items() if v != None]
tags = set([t for i in l for t in i[1]])
print(tags)
l = [(k,v) for k,v in tell.items() if v == None]
l.sort()
print(l[:50])
print(len(l))
# Out:
# {'privacy', 'fame', 'autumn', 'art', 'seasons', 'memory', 'mind', 'wonder', 'love', 'marriage', 'surprise', 'hesitation', 'madness', 'weather', 'sadness', 'sickness', 'summer', 'scorn', 'frustration', 'disconnection', 'peace', 'work', 'imagination', 'faith', 'sleep', 'mystery', 'fear', 'determination', 'friendship', 'woman', 'trees', 'suffering', 'birds', 'smallness', 'winter', 'mother', 'loss', 'children', 'insects', 'salvation', 'beauty', 'flowers', 'grace', 'life', 'spring', 'freedom', 'happiness', 'connection', 'death', 'falsehood', 'science', 'family', 'nature', 'time'}
# []
# 0

# %%
# l = [(k,v) for k,v in tell.items() if v == None]

# l.sort()
# print (l[:50])

    
with open(inf, 'rb') as infile:
    
    tell = pickle.load(infile)

tag_count = defaultdict(int)

for tag in tags:
    
    p_count = 0
    s_count = 0
    total = 0
    
    for poem in tell:
        
        if tag in tell[poem][0]:
            p_count += 1
        if tag in tell[poem][1]:
            s_count +=1 
            
    tag_count[tag] = (p_count, s_count, p_count+s_count)

print(tag_count)

s = [(k, v) for k,v in tag_count.items()]
print(sorted(s, key=lambda x: x[1][2], reverse=True))
# Out:
# defaultdict(<class 'int'>, {'privacy': (1, 2, 3), 'fame': (2, 0, 2), 'autumn': (0, 2, 2), 'art': (7, 1, 8), 'seasons': (2, 3, 5), 'memory': (6, 3, 9), 'mind': (10, 5, 15), 'wonder': (15, 39, 54), 'love': (10, 8, 18), 'marriage': (1, 3, 4), 'surprise': (0, 3, 3), 'hesitation': (0, 1, 1), 'madness': (1, 1, 2), 'weather': (4, 3, 7), 'sadness': (1, 11, 12), 'sickness': (2, 1, 3), 'summer': (2, 0, 2), 'scorn': (3, 10, 13), 'frustration': (0, 7, 7), 'disconnection': (5, 8, 13), 'peace': (9, 11, 20), 'work': (0, 1, 1), 'imagination': (1, 2, 3), 'faith': (6, 8, 14), 'sleep': (0, 3, 3), 'mystery': (4, 7, 11), 'fear': (1, 5, 6), 'determination': (6, 6, 12), 'friendship': (1, 2, 3), 'woman': (1, 0, 1), 'trees': (1, 0, 1), 'suffering': (19, 15, 34), 'birds': (7, 1, 8), 'smallness': (7, 5, 12), 'winter': (1, 1, 2), 'mother': (1, 0, 1), 'loss': (19, 22, 41), 'children': (1, 2, 3), 'insects': (6, 0, 6), 'salvation': (18, 6, 24), 'beauty': (9, 10, 19), 'flowers': (6, 0, 6), 'grace': (14, 8, 22), 'life': (3, 6, 9), 'spring': (1, 0, 1), 'freedom': (3, 2, 5), 'happiness': (9, 7, 16), 'connection': (7, 24, 31), 'death': (37, 15, 52), 'falsehood': (2, 2, 4), 'science': (2, 1, 3), 'family': (3, 0, 3), 'nature': (19, 15, 34), 'time': (9, 10, 19)})
# [('wonder', (15, 39, 54)), ('death', (37, 15, 52)), ('loss', (19, 22, 41)), ('suffering', (19, 15, 34)), ('nature', (19, 15, 34)), ('connection', (7, 24, 31)), ('salvation', (18, 6, 24)), ('grace', (14, 8, 22)), ('peace', (9, 11, 20)), ('beauty', (9, 10, 19)), ('time', (9, 10, 19)), ('love', (10, 8, 18)), ('happiness', (9, 7, 16)), ('mind', (10, 5, 15)), ('faith', (6, 8, 14)), ('scorn', (3, 10, 13)), ('disconnection', (5, 8, 13)), ('sadness', (1, 11, 12)), ('determination', (6, 6, 12)), ('smallness', (7, 5, 12)), ('mystery', (4, 7, 11)), ('memory', (6, 3, 9)), ('life', (3, 6, 9)), ('art', (7, 1, 8)), ('birds', (7, 1, 8)), ('weather', (4, 3, 7)), ('frustration', (0, 7, 7)), ('fear', (1, 5, 6)), ('insects', (6, 0, 6)), ('flowers', (6, 0, 6)), ('seasons', (2, 3, 5)), ('freedom', (3, 2, 5)), ('marriage', (1, 3, 4)), ('falsehood', (2, 2, 4)), ('privacy', (1, 2, 3)), ('surprise', (0, 3, 3)), ('sickness', (2, 1, 3)), ('imagination', (1, 2, 3)), ('sleep', (0, 3, 3)), ('friendship', (1, 2, 3)), ('children', (1, 2, 3)), ('science', (2, 1, 3)), ('family', (3, 0, 3)), ('fame', (2, 0, 2)), ('autumn', (0, 2, 2)), ('madness', (1, 1, 2)), ('summer', (2, 0, 2)), ('winter', (1, 1, 2)), ('hesitation', (0, 1, 1)), ('work', (0, 1, 1)), ('woman', (1, 0, 1)), ('trees', (1, 0, 1)), ('mother', (1, 0, 1)), ('spring', (1, 0, 1))]

# %%
with open("sorted_seed_dict.pickle", 'rb') as inf:
    
    seed_dict = pickle.load(inf)
    
print (seed_dict)
# Out:
# {'initial': (0.0, 1), 'bather': (0.0, 1), 'pyrites': (0.0, 1), 'numidian': (0.0, 1), 'socially': (0.0, 1), 'venetian': (0.0, 1), 'dazzle': (0.0, 1), 'comet': (0.0, 1), 'purchasing': (0.0, 1), 'cell': (0.0, 1), 'bourbon': (0.0, 1), 'preconcerted': (0.0, 1), 'peoples': (0.0, 1), 'anticipate': (0.0, 1), 'angled': (0.0, 1), 'spray': (0.0, 1), 'principally': (0.0, 1), 'equator': (0.0, 1), 'insert': (0.0, 1), 'ray': (0.0, 1), 'perihelion': (0.0, 1), 'incarceration': (0.0, 1), 'merchantman': (0.0, 1), 'stack': (0.0, 1), 'adjective': (0.0, 1), 'executive': (0.0, 1), 'grimace': (0.0, 1), 'folding': (0.0, 1), 'spreading': (0.0, 1), 'wading': (0.0, 1), 'tasting': (0.0, 1), 'gentlefolk': (0.0, 1), 'westward': (0.0, 1), 'temper': (0.0, 1), 'premature': (0.0, 1), 'reindeer': (0.0, 1), 'peg': (0.0, 1), 'subsidy': (0.0, 1), 'substantiate': (0.0, 1), 'lens': (0.0, 1), 'retrieve': (0.0, 1), 'mechanical': (0.0, 1), 'journeying': (0.0, 1), 'empress': (0.0, 1), 'obelisk': (0.0, 1), 'bade': (0.0, 1), 'workman': (0.0, 1), 'estranging': (0.0, 1), 'normal': (0.0, 1), 'fissure': (0.0, 1), 'article': (0.0, 1), 'vespers': (0.0, 1), 'powder': (0.0, 1), 'incognito': (0.0, 1), 'raft': (0.0, 1), 'chatter': (0.0, 1), 'affirmed': (0.0, 1), 'dingle': (0.0, 1), 'redden': (0.0, 1), 'impute': (0.0, 1), 'pour': (0.0, 1), 'rhinoceros': (0.0, 1), 'debt': (0.0, 1), 'inconceivably': (0.0, 1), 'mandolin': (0.0, 1), 'andes': (0.0, 1), 'rendezvous': (0.0, 1), 'twitter': (0.0, 1), 'sprite': (0.0, 1), 'retard': (0.0, 1), 'examine': (0.0, 1), 'pounce': (0.0, 1), 'instability': (0.0, 1), 'cloak': (0.0, 1), 'leaden': (0.0, 1), 'envoy': (0.0, 1), 'strategist': (0.0, 1), 'sallow': (0.0, 1), 'rings': (0.0, 1), 'argent': (0.0, 1), 'ruff': (0.0, 1), 'b': (0.0, 1), 'sessions': (0.0, 1), 'clap': (0.0, 1), 'allied': (0.0, 1), 'prima': (0.0, 1), 'persuasive': (0.0, 1), 'indolent': (0.0, 1), 'snugly': (0.0, 1), 'placard': (0.0, 1), 'yarn': (0.0, 1), 'major': (0.0, 1), 'antiquity': (0.0, 1), 'mausoleum': (0.0, 1), 'establish': (0.0, 1), 'perch': (0.0, 1), 'civilization': (0.0, 1), 'bowl': (0.0, 1), 'constellation': (0.0, 1), 'acknowledgment': (0.0, 1), 'whist': (0.0, 1), 'argument': (0.0, 1), 'emigrate': (0.0, 1), 'sleeve': (0.0, 1), 'driving': (0.0, 1), 'puppet': (0.0, 1), 'office': (0.0, 1), 'jib': (0.0, 1), 'robbins': (0.0, 1), 'undertaking': (0.0, 1), 'pompeii': (0.0, 1), 'prompter': (0.0, 1), 'game': (0.0, 1), 'vaunt': (0.0, 1), 'pledge': (0.0, 1), 'guitar': (0.0, 1), 'oak': (0.0, 1), 'reed': (0.0, 1), 'pointed': (0.0, 1), 'preferment': (0.0, 1), 'stump': (0.0, 1), 'thrum': (0.0, 1), 'hyphen': (0.0, 1), 'burgundy': (0.0, 1), 'bitterness': (0.0, 1), 'energy': (0.0, 1), 'beck': (0.0, 1), 'crystal': (0.0, 1), 'chalk': (0.0, 1), 'government': (0.0, 1), 'investment': (0.0, 1), 'shaw': (0.0, 1), 'softened': (0.0, 1), 'hollow': (0.0, 1), 'corruption': (0.0, 1), 'tramp': (0.0, 1), 'motive': (0.0, 1), 'seventy': (0.0, 1), 'insight': (0.0, 1), 'variety': (0.0, 1), 'marquis': (0.0, 1), 'chronicle': (0.0, 1), 'confederate': (0.0, 1), 'ripple': (0.0, 1), 'ananias': (0.0, 1), 'bearded': (0.0, 1), 'cuticle': (0.0, 1), 'reel': (0.0, 1), 'festival': (0.0, 1), 'preserved': (0.0, 1), 'identify': (0.0, 1), 'trench': (0.0, 1), 'devise': (0.0, 1), 'boom': (0.0, 1), 'tripoli': (0.0, 1), 'paris': (0.0, 1), 'hood': (0.0, 1), 'cambric': (0.0, 1), 'agent': (0.0, 1), 'irony': (0.0, 1), 'oversleep': (0.0, 1), 'aromatic': (0.0, 1), 'objection': (0.0, 1), 'premises': (0.0, 1), 'defaulter': (0.0, 1), 'emergency': (0.0, 1), 'sarah': (0.0, 1), 'strait': (0.0, 1), 'sear': (0.0, 1), 'renounce': (0.0, 1), 'defending': (0.0, 1), 'sounding': (0.0, 1), 'vitalize': (0.0, 1), 'graphic': (0.0, 1), 'enamel': (0.0, 1), 'resource': (0.0, 1), 'flambeau': (0.0, 1), 'decision': (0.0, 1), 'tribunal': (0.0, 1), 'sepal': (0.0, 1), 'seventeenth': (0.0, 1), 'ornithology': (0.0, 1), 'elderly': (0.0, 1), 'ransom': (0.0, 1), 'allotted': (0.0, 1), 'colonnade': (0.0, 1), 'madam': (0.0, 1), 'gaudy': (0.0, 1), 'chink': (0.0, 1), 'exasperate': ...

# %%
########################## GENERATING SEPARATE POEM FILES BY POEM NUMBER #################

import pickle
import json
import re
import string

inf = open("edCompleteNoDash.txt", 'r')

buff = ""
out = open("./edCompleteNoDash/0.txt", 'w') # dummy file to let loop work 

for line in inf:
    
    if re.match('[0-9]+', line[:-1]):  # line indicates new poem number
        
        out.write(buff) # store previous poem
        out.close()
        
        out = open("./edCompleteNoDash/{}.txt".format(int(line[:-1])), 'w')
        
        buff = line # buff now starts with new poem number
        
    else:
        
        buff = buff + line
        
out.write(buff)
out.close()
inf.close()

os.remove("./edCompleteNoDash/0.txt")  # kill dummy file

# %%
################## GENERATING LOWERCASE POEM FILES WITH ONLY APOSTROPHES REMAINING ##################

import pickle
import json
import re
import string
import os


root = './edCompleteNoDash'
newdir = './edCompleteSimple'

buff = ""

for filename in os.listdir(root):
    
    inf = open(os.path.join(root, filename), 'r')
    out = open(os.path.join(newdir, filename), 'w')
    
    for line in inf:
        
        buff = line.replace("-", "")
        buff = line.replace("!", "")
        buff = buff.replace("?", "")
        buff = buff.replace(",", "")
        buff = buff.replace(".", "")
        buff = buff.replace(";", "")
        buff = buff.replace(":", "")
        buff = buff.replace("\"", "")
        buff = buff.lower()
        
        out.write(buff)
    
    inf.close()
    out.close()

# %%
############ BASELINE POEM AFFECT SCORE CALCULATOR ###################

import pickle
import json
import os
from collections import defaultdict

with open("sent_dict.json", 'rb') as f:
    sent_dict = json.load(f)

root = './edCompleteSimple'

# k:v is poem number:(AS density per hitcount, AS density per wordcount)
# where hitcount = num words with scores found in sent_dict
# and wordcount = total words in poem

AS_dict = defaultdict(float)
alpha = (1/1000)
    
for filename in os.listdir(root):
    
    with open(os.path.join(root, filename), 'r') as inf:
        buff = inf.read().split()
        
    del buff[0]  # remove poem number
    
    hitcount = 0   # num words with score in sent_dict
    AS_total = 0
    
    for word in buff:
        
        if word in sent_dict.keys():
            
            hitcount += 1
            AS_total += sent_dict[word]
            
        else:
            
            AS_total += alpha
    
    AS_dict[filename[:-4]] = (AS_total/hitcount, AS_total/len(buff))


with open("AS_dict_alpha3.json", 'w') as f:
    json.dump(AS_dict, f)
    
with open("AS_dict_alpha3.pickle", 'wb') as f:
    pickle.dump(AS_dict, f)

# %%
############### PRINT AS VALUES PER WORD IN A POEM #############

with open("./edCompleteSimple/1660.txt", 'r') as f:
    buff = f.read().split()
    del buff[0]
    
for word in buff:
    if word in sent_dict.keys():
        print(word, ":", sent_dict[word])
    else:
        print(word, ": NOT IN DICT")
# Out:
# glory : -0.125
# is : NOT IN DICT
# that : NOT IN DICT
# bright : -0.25
# tragic : -0.125
# thing : 0.0
# that : NOT IN DICT
# for : NOT IN DICT
# an : NOT IN DICT
# instant : 0.0
# means : 0.0
# dominion : 0.0
# warms : NOT IN DICT
# some : 0.25
# poor : -0.125
# name : 0.25
# that : NOT IN DICT
# never : -0.125
# felt : 0.0
# the : NOT IN DICT
# sun : 0.0
# gently : 0.125
# replacing : 0.0
# in : 0.0
# oblivion : 0.125

# %%
########## TOKEN COUNTER #################

tokens = defaultdict(int)
total = 0

for filename in os.listdir("./edCompleteSimple"):
    
    with open(os.path.join("./edCompleteSimple", filename), 'r') as inf:
        
        buff = inf.read().split()
        del buff[0]
        
        for word in buff:
            
            total += 1
            tokens[word] += 1

print(len(tokens))
print(total)
# Out:
# 10933
# 94424

# %%
with open("AS_dict.json", 'r') as f:
    AS_dict = json.load(f)

total = 0
stripped = 0
    
for poem in AS_dict:
    
    total += AS_dict[poem][1]
    stripped += AS_dict[poem][0]
    
total = total/1775
stripped = stripped/1775

print("stripped:",stripped)
print("total:",total)
# Out:
# stripped: -0.01674882500181354
# total: -0.008913926388702005

# %%
print(tags)
# Out:
# {'privacy', 'fame', 'autumn', 'art', 'seasons', 'memory', 'mind', 'wonder', 'love', 'marriage', 'surprise', 'hesitation', 'madness', 'weather', 'sadness', 'sickness', 'summer', 'scorn', 'frustration', 'disconnection', 'peace', 'work', 'imagination', 'faith', 'sleep', 'mystery', 'fear', 'determination', 'friendship', 'woman', 'trees', 'suffering', 'birds', 'smallness', 'winter', 'mother', 'loss', 'children', 'insects', 'salvation', 'beauty', 'flowers', 'grace', 'life', 'spring', 'freedom', 'happiness', 'connection', 'death', 'falsehood', 'science', 'family', 'nature', 'time'}

# %%
with open("AS_dict.json", 'rb') as f:
    AS_dict = json.load(f)

    
for poem in AS_dict:
    
    if 'death' in tell[poem]:
        print(poem,":",AS_dict['{}'.format(poem)])
# Out:
# {'1697': [-0.02631578947368421, -0.01282051282051282], '1064': [-0.022727272727272728, -0.011904761904761904], '750': [-0.003472222222222222, -0.001984126984126984], '1368': [0.1125, 0.05625], '234': [-0.03, -0.012295081967213115], '1573': [0.006944444444444444, 0.0026041666666666665], '439': [-0.01875, -0.010135135135135136], '583': [-0.06896428571428571, -0.03862], '916': [-0.0390625, -0.01644736842105263], '1627': [-0.0375, -0.020833333333333332], '1348': [-0.04411764705882353, -0.025], '921': [-0.05434782608695652, -0.03289473684210526], '455': [-0.03409090909090909, -0.020833333333333332], '779': [-0.08928571428571429, -0.03676470588235294], '1775': [-0.028846153846153848, -0.010416666666666666], '1774': [-0.13392857142857142, -0.08152173913043478], '657': [0.028409090909090908, 0.0125], '1094': [-0.019230769230769232, -0.01], '17': [-0.09239130434782608, -0.059027777777777776], '1148': [0.007352941176470588, 0.0035714285714285713], '219': [-0.004629629629629629, -0.0018656716417910447], '230': [-0.009259259259259259, -0.005154639175257732], '1010': [0.0125, 0.005813953488372093], '886': [0.010416666666666666, 0.004807692307692308], '323': [-0.018739130434782612, -0.009577777777777779], '92': [0.04861111111111111, 0.03017241379310345], '1380': [0.041666666666666664, 0.019736842105263157], '1751': [-0.08035714285714286, -0.03515625], '208': [-0.08334883720930232, -0.042666666666666665], '1165': [-0.015625, -0.007352941176470588], '1306': [0.0, 0.0], '80': [-0.03365384615384615, -0.021875], '1748': [-0.07407407407407407, -0.038461538461538464], '1029': [-0.09375, -0.0375], '998': [0.036458333333333336, 0.021875], '692': [-0.0755813953488372, -0.03735632183908046], '1535': [0.057291666666666664, 0.030555555555555555], '57': [0.0625, 0.02403846153846154], '909': [-0.029411764705882353, -0.015625], '766': [-0.031914893617021274, -0.015625], '1740': [0.03676470588235294, 0.01488095238095238], '473': [0.0, 0.0], '1364': [-0.0390625, -0.015625], '888': [-0.03125, -0.017045454545454544], '604': [0.03618421052631579, 0.017857142857142856], '168': [0.0029069767441860465, 0.0013736263736263737], '740': [-0.09375, -0.04233870967741935], '832': [-0.125, -0.06666666666666667], '127': [0.046875, 0.024456521739130436], '1556': [0.011363636363636364, 0.00625], '486': [-0.04974, -0.02645744680851064], '484': [0.0125, 0.005681818181818182], '1367': [-0.045454545454545456, -0.019230769230769232], '883': [0.04807692307692308, 0.023148148148148147], '760': [-0.0575, -0.02875], '1228': [0.003289473684210526, 0.001893939393939394], '1341': [0.05, 0.027777777777777776], '1456': [-0.0673076923076923, -0.03977272727272727], '1205': [-0.03125, -0.01488095238095238], '1024': [0.03333333333333333, 0.017241379310344827], '563': [0.003472222222222222, 0.001838235294117647], '609': [-0.0234375, -0.012], '1555': [-0.09027777777777778, -0.039634146341463415], '246': [-0.02702702702702703, -0.01282051282051282], '11': [0.01358695652173913, 0.006188118811881188], '276': [-0.048295454545454544, -0.027597402597402596], '1285': [-0.0625, -0.03353658536585366], '1037': [-0.0625, -0.02976190476190476], '1035': [-0.016304347826086956, -0.007653061224489796], '823': [-0.013888888888888888, -0.005], '550': [0.014344262295081968, 0.007675438596491228], '1268': [-0.0625, -0.03125], '211': [0.038461538461538464, 0.015625], '559': [-0.04941860465116279, -0.027960526315789474], '24': [0.007911392405063292, 0.004528985507246377], '1483': [0.03125, 0.016544117647058824], '330': [0.0, 0.0], '1243': [-0.11805555555555555, -0.059027777777777776], '553': [-0.03365384615384615, -0.015086206896551725], '913': [0.015, 0.00872093023255814], '97': [-0.1015625, -0.04513888888888889], '799': [-0.09375, -0.05048076923076923], '1013': [-0.09558823529411764, -0.040625], '892': [0.028333333333333332, 0.014756944444444444], '224': [-0.013888888888888888, -0.005813953488372093], '708': [-0.041666666666666664, -0.026785714285714284], '949': [-0.003048780487804878, -0.0016233766233766235], '1 ...
